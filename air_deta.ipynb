# %%
import requests
import json
import os

API_KEY = "51cf8e27aa2e706d010c3ce4612740a7"

def get_weather(lat, lon):
    url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_KEY}&units=metric"

    try:
        res = requests.get(url)
        res.raise_for_status()
        data = res.json()

        return {
            "temperature": data["main"]["temp"],
            "humidity": data["main"]["humidity"],
            "condition": data["weather"][0]["main"],
            "wind_speed": data["wind"]["speed"]
        }

    except Exception as e:
        return {"error": str(e)}

weather = get_weather(35.68, 139.76)

import datetime

month = datetime.datetime.now().month

def get_season(month):
    if 3 <= month <= 5: return "spring"
    if 6 <= month <= 8: return "summer"
    if 9 <= month <= 11: return "autumn"
    return "winter"

print(API_KEY)
print(json.dumps(weather, indent=2, ensure_ascii=False))
# Out:
# 51cf8e27aa2e706d010c3ce4612740a7
# {
#   "temperature": 16.97,
#   "humidity": 49,
#   "condition": "Clouds",
#   "wind_speed": 7.32
# }
